# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
from torch.utils.data import Dataset, DataLoader
import torch

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /teamspace/studios/this_studio/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /teamspace/studios/this_studio/nltk_data...
# True

# %%
import nltk
from torch.utils.data import Dataset, DataLoader
import torch

# Download the tokenizer models
nltk.download('punkt_tab')

# Tokenizer functions using NLTK
def tokenize_en(text):
    return nltk.word_tokenize(text)

def tokenize_de(text):
    return nltk.word_tokenize(text)

# Simple Vocabulary to map words to integer indices
class Vocabulary:
    def __init__(self):
        self.word2idx = {}
        self.idx2word = {}
        self.idx = 0

    def add_word(self, word):
        if word not in self.word2idx:
            self.word2idx[word] = self.idx
            self.idx2word[self.idx] = word
            self.idx += 1

    def add_sentence(self, sentence):
        for word in sentence:
            self.add_word(word)

    def __len__(self):
        return len(self.word2idx)

    def numericalize(self, sentence):
        return [self.word2idx[word] for word in sentence]

# Dataset class using NLTK tokenization
class NLTKTranslationDataset(Dataset):
    def __init__(self, data, src_vocab, tgt_vocab, src_tokenizer, tgt_tokenizer):
        self.data = data
        self.src_vocab = src_vocab
        self.tgt_vocab = tgt_vocab
        self.src_tokenizer = src_tokenizer
        self.tgt_tokenizer = tgt_tokenizer

        # Build the vocabulary for both source and target languages
        for src_text, tgt_text in data:
            self.src_vocab.add_sentence(self.src_tokenizer(src_text))
            self.tgt_vocab.add_sentence(self.tgt_tokenizer(tgt_text))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        src_text, tgt_text = self.data[idx]
        src_tokens = self.src_tokenizer(src_text)
        tgt_tokens = self.tgt_tokenizer(tgt_text)
        src_indices = self.src_vocab.numericalize(src_tokens)
        tgt_indices = self.tgt_vocab.numericalize(tgt_tokens)
        return src_indices, tgt_indices

def prepare_data(batch_size=32):
    # Simulated dataset (you can load a real dataset here)
    data = [("Hello world", "Hallo Welt"), ("How are you?", "Wie geht es Ihnen?")]

    # Create vocabularies
    src_vocab = Vocabulary()
    tgt_vocab = Vocabulary()

    # Define dataset
    dataset = NLTKTranslationDataset(data, src_vocab, tgt_vocab, tokenize_en, tokenize_de)

    # Create DataLoader for batching
    data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)

    return data_loader

# Collate function to pad sequences to the same length
def collate_fn(batch):
    src_batch, tgt_batch = zip(*batch)

    # Find the maximum length of source and target sequences in the batch
    src_max_len = max([len(src) for src in src_batch])
    tgt_max_len = max([len(tgt) for tgt in tgt_batch])

    # Padding token (assume 0 is the padding index)
    PAD_IDX = 0

    # Pad the source and target sequences
    src_padded = [src + [PAD_IDX] * (src_max_len - len(src)) for src in src_batch]
    tgt_padded = [tgt + [PAD_IDX] * (tgt_max_len - len(tgt)) for tgt in tgt_batch]

    # Convert the lists to PyTorch tensors
    src_tensor = torch.tensor(src_padded, dtype=torch.long)
    tgt_tensor = torch.tensor(tgt_padded, dtype=torch.long)

    return src_tensor, tgt_tensor

if __name__ == "__main__":
    data_loader = prepare_data()
    for src_batch, tgt_batch in data_loader:
        print(f"Source batch: {src_batch}")
        print(f"Target batch: {tgt_batch}")
# Out:
# Source batch: tensor([[0, 1, 0, 0],
#         [2, 3, 4, 5]])
# Target batch: tensor([[0, 1, 0, 0, 0],
#         [2, 3, 4, 5, 6]])
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /teamspace/studios/this_studio/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
pip install librosa
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 127.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 71.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 MB 156.6 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import librosa

# %%
# !pip install librosa

# %%
import os

wav_file_path = "adsız.wav"  # Dosya sadece ismiyle belirtildiğinde
print(os.path.abspath(wav_file_path))  # Bu, dosyanın tam yolunu gösterecektir
# Out:
# /teamspace/studios/this_studio/adsız.wav

# %%
import librosa

# Dosya yolunu güncelleyin
wav_file_path = "/teamspace/studios/this_studio/adsız.wav"

# WAV dosyasını yükleme
audio_data, sample_rate = librosa.load(wav_file_path, sr=None)

# Audio verisi ve örnekleme hızı hakkında bilgi yazdırma
print("Sample Rate:", sample_rate)
# Out:
# Sample Rate: 44100

# %%
import librosa

# Dosya yolunu belirtiyoruz
wav_file_path = "/teamspace/studios/this_studio/adsız.wav"

# WAV dosyasını yükleme
audio_data, sample_rate = librosa.load(wav_file_path, sr=None)

# Audio verisi ve örnekleme hızı hakkında bilgi yazdırma
print("Sample Rate:", sample_rate)
# Out:
# Sample Rate: 44100

# %%
# !python data_preparation.py
# Out:
# /home/zeus/miniconda3/envs/cloudspace/bin/python: can't open file '/teamspace/studios/this_studio/data_preparation.py': [Errno 2] No such file or directory

# %%
import subprocess

# Dosya yolunu belirtiyoruz
file_path = "/teamspace/studios/this_studio/data_preparation.py"

# Dosyayı çalıştırıyoruz
subprocess.run(["python", file_path])
# Out:
# /home/zeus/miniconda3/envs/cloudspace/bin/python: can't open file '/teamspace/studios/this_studio/data_preparation.py': [Errno 2] No such file or directory
# CompletedProcess(args=['python', '/teamspace/studios/this_studio/data_preparation.py'], returncode=2)

# %%
ls /teamspace/studios/this_studio
# Out:
#  1.pdf*                encoder.json*             previous_chapters_4.py*
#  2.pdf*                gpt2/                     requirements-extra.txt*
#  3.pdf*                gpt2_model/               simple_model.pth*
# 'Untitled Folder'/     gpt_download.py*          sms_spam_collection/
#  Untitled.ipynb*       loss-plot.pdf*            sms_spam_collection.zip*
#  Untitled1.ipynb*      main.py*                  test.csv*
#  Untitled2.ipynb       model.pth*                the-verdict.txt*
#  Untitled3.ipynb       nltk_data/                train.csv*
#  __pycache__/          previous_chapters.py*     validation.csv*
#  adsız.wav             previous_chapters_2.py*   vocab.bpe*
#  bpe_openai_gpt2.py*   previous_chapters_3.py*

# %%
import os
wav_file_path = "/teamspace/studios/this_studio/adsız.wav"
print(os.path.exists(wav_file_path))  # True dönerse dosya mevcut
# Out:
# True

# %%
pip install pydub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pydub import AudioSegment

# Dosya yolunu belirtiyoruz
wav_file_path = "/teamspace/studios/this_studio/adsız.wav"

# WAV dosyasını yükleme
audio = AudioSegment.from_wav(wav_file_path)

# Audio verisi hakkında bilgi yazdırma
print("Channels:", audio.channels)
print("Sample Width:", audio.sample_width)
print("Frame Rate:", audio.frame_rate)
# Out:
# Channels: 1
# Sample Width: 2
# Frame Rate: 44100
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
pip install SpeechRecognition
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 179.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pydub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import speech_recognition as sr
from pydub import AudioSegment
import nltk
from torch.utils.data import Dataset, DataLoader
import torch

# Download the tokenizer models
nltk.download('punkt')

# Tokenizer functions using NLTK
def tokenize_en(text):
    return nltk.word_tokenize(text)

def tokenize_de(text):
    return nltk.word_tokenize(text)

# Simple Vocabulary to map words to integer indices
class Vocabulary:
    def __init__(self):
        self.word2idx = {}
        self.idx2word = {}
        self.idx = 0

    def add_word(self, word):
        if word not in self.word2idx:
            self.word2idx[word] = self.idx
            self.idx2word[self.idx] = word
            self.idx += 1

    def add_sentence(self, sentence):
        for word in sentence:
            self.add_word(word)

    def __len__(self):
        return len(self.word2idx)

    def numericalize(self, sentence):
        return [self.word2idx[word] for word in sentence]

# Function to convert .wav to text using speech_recognition
def audio_to_text(wav_file_path):
    recognizer = sr.Recognizer()
    audio = AudioSegment.from_wav(wav_file_path)
    audio = audio.set_channels(1).set_frame_rate(16000)  # Adjust the audio if needed
    
    # Saving the processed audio temporarily
    audio.export("temp_audio.wav", format="wav")

    with sr.AudioFile("temp_audio.wav") as source:
        audio_data = recognizer.record(source)
        try:
            # Using Google's Speech-to-Text API to convert audio to text
            text = recognizer.recognize_google(audio_data)
            return text
        except sr.UnknownValueError:
            return "Google Speech Recognition could not understand audio"
        except sr.RequestError as e:
            return f"Could not request results from Google Speech Recognition service; {e}"

# Dataset class using NLTK tokenization
class NLTKTranslationDataset(Dataset):
    def __init__(self, data, src_vocab, tgt_vocab, src_tokenizer, tgt_tokenizer):
        self.data = data
        self.src_vocab = src_vocab
        self.tgt_vocab = tgt_vocab
        self.src_tokenizer = src_tokenizer
        self.tgt_tokenizer = tgt_tokenizer

        # Build the vocabulary for both source and target languages
        for src_text, tgt_text in data:
            self.src_vocab.add_sentence(self.src_tokenizer(src_text))
            self.tgt_vocab.add_sentence(self.tgt_tokenizer(tgt_text))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        src_text, tgt_text = self.data[idx]
        src_tokens = self.src_tokenizer(src_text)
        tgt_tokens = self.tgt_tokenizer(tgt_text)
        src_indices = self.src_vocab.numericalize(src_tokens)
        tgt_indices = self.tgt_vocab.numericalize(tgt_tokens)
        return src_indices, tgt_indices

# Collate function to pad sequences to the same length
def collate_fn(batch):
    src_batch, tgt_batch = zip(*batch)
    src_max_len = max([len(src) for src in src_batch])
    tgt_max_len = max([len(tgt) for tgt in tgt_batch])
    
    PAD_IDX = 0
    src_padded = [src + [PAD_IDX] * (src_max_len - len(src)) for src in src_batch]
    tgt_padded = [tgt + [PAD_IDX] * (tgt_max_len - len(tgt)) for tgt in tgt_batch]

    src_tensor = torch.tensor(src_padded, dtype=torch.long)
    tgt_tensor = torch.tensor(tgt_padded, dtype=torch.long)

    return src_tensor, tgt_tensor

def prepare_data(wav_file_path, batch_size=32):
    # Convert the audio to text
    src_text = audio_to_text(wav_file_path)
    
    # Simulated target text (you can replace it with actual target language text)
    tgt_text = "This is the translated text"

    data = [(src_text, tgt_text)]

    # Create vocabularies
    src_vocab = Vocabulary()
    tgt_vocab = Vocabulary()

    # Define dataset
    dataset = NLTKTranslationDataset(data, src_vocab, tgt_vocab, tokenize_en, tokenize_de)

    # Create DataLoader for batching
    data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)

    return data_loader

if __name__ == "__main__":
    wav_file_path = "/teamspace/studios/this_studio/adsız.wav"
    data_loader = prepare_data(wav_file_path)
    for src_batch, tgt_batch in data_loader:
        print(f"Source batch: {src_batch}")
        print(f"Target batch: {tgt_batch}")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /teamspace/studios/this_studio/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Source batch: tensor([[0, 1, 1, 2, 3]])
# Target batch: tensor([[0, 1, 2, 3, 4]])

# %%
import torch
import torch.nn as nn
import math

# Embedding Layer
class TokenEmbedding(nn.Module):
    def __init__(self, vocab_size, embed_size):
        super(TokenEmbedding, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_size)
        
    def forward(self, x):
        return self.embedding(x)

# Positional Encoding
class PositionalEncoding(nn.Module):
    def __init__(self, embed_size, max_len=512):
        super(PositionalEncoding, self).__init__()
        pe = torch.zeros(max_len, embed_size)
        for pos in range(max_len):
            for i in range(0, embed_size, 2):
                pe[pos, i] = math.sin(pos / (10000 ** ((2 * i)/embed_size)))
                pe[pos, i + 1] = math.cos(pos / (10000 ** ((2 * (i + 1))/embed_size)))
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)
        
    def forward(self, x):
        return x + self.pe[:, :x.size(1)]

# Scaled Dot-Product Attention
class ScaledDotProductAttention(nn.Module):
    def __init__(self, d_k):
        super(ScaledDotProductAttention, self).__init__()
        self.d_k = d_k
    
    def forward(self, Q, K, V, mask=None):
        scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(self.d_k)
        if mask is not None:
            scores = scores.masked_fill(mask == 0, -1e9)
        attn = torch.nn.functional.softmax(scores, dim=-1)
        output = torch.matmul(attn, V)
        return output, attn

# Multi-Head Attention
class MultiHeadAttention(nn.Module):
    def __init__(self, heads, d_model):
        super(MultiHeadAttention, self).__init__()
        assert d_model % heads == 0
        self.d_k = d_model // heads
        self.heads = heads
        self.W_q = nn.Linear(d_model, d_model)
        self.W_k = nn.Linear(d_model, d_model)
        self.W_v = nn.Linear(d_model, d_model)
        self.fc = nn.Linear(d_model, d_model)
        self.attention = ScaledDotProductAttention(self.d_k)
    
    def forward(self, Q, K, V, mask=None):
        batch_size = Q.size(0)
        Q = self.W_q(Q).view(batch_size, -1, self.heads, self.d_k).transpose(1, 2)
        K = self.W_k(K).view(batch_size, -1, self.heads, self.d_k).transpose(1, 2)
        V = self.W_v(V).view(batch_size, -1, self.heads, self.d_k).transpose(1, 2)
        scores, attn = self.attention(Q, K, V, mask)
        scores = scores.transpose(1, 2).contiguous().view(batch_size, -1, self.heads * self.d_k)
        output = self.fc(scores)
        return output

# Feedforward Layer
class FeedForward(nn.Module):
    def __init__(self, d_model, d_ff, dropout=0.1):
        super(FeedForward, self).__init__()
        self.fc1 = nn.Linear(d_model, d_ff)
        self.fc2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.dropout(self.relu(self.fc1(x)))
        x = self.fc2(x)
        return x

# Encoder Layer
class EncoderLayer(nn.Module):
    def __init__(self, d_model, heads, d_ff, dropout=0.1):
        super(EncoderLayer, self).__init__()
        self.attention = MultiHeadAttention(heads, d_model)
        self.norm1 = nn.LayerNorm(d_model)
        self.ff = FeedForward(d_model, d_ff, dropout)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, mask=None):
        # Multi-head attention with residual connection and layer normalization
        attn_output = self.attention(x, x, x, mask)
        x = self.norm1(x + self.dropout(attn_output))
        
        # Feedforward network with residual connection and layer normalization
        ff_output = self.ff(x)
        x = self.norm2(x + self.dropout(ff_output))
        return x

# Encoder
class Encoder(nn.Module):
    def __init__(self, vocab_size, d_model, N, heads, d_ff, dropout=0.1):
        super(Encoder, self).__init__()
        self.embedding = TokenEmbedding(vocab_size, d_model)
        self.positional_encoding = PositionalEncoding(d_model)
        self.layers = nn.ModuleList([EncoderLayer(d_model, heads, d_ff, dropout) for _ in range(N)])
        self.dropout = nn.Dropout(dropout)
    
    def forward(self, x, mask=None):
        x = self.embedding(x)
        x = self.positional_encoding(x)
        for layer in self.layers:
            x = layer(x, mask)
        return x

# Decoder Layer
class DecoderLayer(nn.Module):
    def __init__(self, d_model, heads, d_ff, dropout=0.1):
        super(DecoderLayer, self).__init__()
        self.attention = MultiHeadAttention(heads, d_model)
        self.encoder_attention = MultiHeadAttention(heads, d_model)
        self.ff = FeedForward(d_model, d_ff, dropout)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, enc_output, src_mask=None, tgt_mask=None):
        # Self-attention with residual connection and layer normalization
        attn_output = self.attention(x, x, x, tgt_mask)
        x = self.norm1(x + self.dropout(attn_output))

        # Attention over encoder output
        attn_output = self.encoder_attention(x, enc_output, enc_output, src_mask)
        x = self.norm2(x + self.dropout(attn_output))

        # Feedforward network with residual connection and layer normalization
        ff_output = self.ff(x)
        x = self.norm3(x + self.dropout(ff_output))
        return x

# Decoder
class Decoder(nn.Module):
    def __init__(self, vocab_size, d_model, N, heads, d_ff, dropout=0.1):
        super(Decoder, self).__init__()
        self.embedding = TokenEmbedding(vocab_size, d_model)
        self.positional_encoding = PositionalEncoding(d_model)
        self.layers = nn.ModuleList([DecoderLayer(d_model, heads, d_ff, dropout) for _ in range(N)])
        self.dropout = nn.Dropout(dropout)
    
    def forward(self, x, enc_output, src_mask=None, tgt_mask=None):
        x = self.embedding(x)
        x = self.positional_encoding(x)
        for layer in self.layers:
            x = layer(x, enc_output, src_mask, tgt_mask)
        return x

# Transformer Model
class Transformer(nn.Module):
    def __init__(self, src_vocab_size, tgt_vocab_size, d_model, N, heads, d_ff, dropout=0.1):
        super(Transformer, self).__init__()
        self.encoder = Encoder(src_vocab_size, d_model, N, heads, d_ff, dropout)
        self.decoder = Decoder(tgt_vocab_size, d_model, N, heads, d_ff, dropout)
        self.fc_out = nn.Linear(d_model, tgt_vocab_size)
    
    def forward(self, src, tgt, src_mask=None, tgt_mask=None):
        enc_output = self.encoder(src, src_mask)
        dec_output = self.decoder(tgt, enc_output, src_mask, tgt_mask)
        output = self.fc_out(dec_output)
        return output

    def make_masks(self, src, tgt):
        # Create padding mask for source and target sequences
        src_mask = create_padding_mask(src)
        tgt_padding_mask = create_padding_mask(tgt)
        
        # Create look-ahead mask for the target sequence
        look_ahead_mask = create_look_ahead_mask(tgt.size(1))
        tgt_mask = torch.max(tgt_padding_mask, look_ahead_mask)
        
        return src_mask, tgt_mask

# Padding Mask (prevents attention to padding tokens)
def create_padding_mask(seq):
    mask = (seq == 0).unsqueeze(1).unsqueeze(2)  # (batch_size, 1, 1, seq_len)
    return mask  # Mask with shape (batch_size, 1, 1, seq_len)

# Look-Ahead Mask (prevents attention to future tokens)
def create_look_ahead_mask(size):
    mask = torch.triu(torch.ones((size, size)), diagonal=1).type(torch.uint8)
    return mask  # Shape (seq_len, seq_len)

# %%
def test_transformer():
    # Model parametreleri
    src_vocab_size = 10000  # Gerçek vocab boyutunu burada kullanın
    tgt_vocab_size = 10000  # Gerçek vocab boyutunu burada kullanın
    d_model = 512
    heads = 8
    N = 6  # Encoder/Decoder katman sayısı
    d_ff = 2048
    dropout = 0.1

    # Modeli başlatma
    model = Transformer(src_vocab_size, tgt_vocab_size, d_model, N, heads, d_ff, dropout)

    # Ses dosyasının yolu (örnek)
    wav_file_path = "/teamspace/studios/this_studio/adsız.wav"  # Burayı uygun bir yol ile değiştirin

    # Veri yükleyicisini hazırlama (test için simüle edilmiş veriler)
    data_loader = prepare_data(wav_file_path, batch_size=2)

    # Veri yükleyicisinden bir batch alın
    for src_batch, tgt_batch in data_loader:
        print(f"Source batch: {src_batch}")
        print(f"Target batch: {tgt_batch}")

        # Modelin girdi ve çıktısı
        src_input = src_batch
        tgt_input = tgt_batch[:, :-1]  # Son token'ı çıkarıyoruz
        tgt_output = tgt_batch[:, 1:]  # İlk token'ı çıkarıyoruz

        # Maskeleri oluşturma
        src_mask, tgt_mask = model.make_masks(src_input, tgt_input)

        # Modelden geçiş
        output = model(src_input, tgt_input, src_mask, tgt_mask)

        # Model çıkışını kontrol etme
        print(f"Model output shape: {output.shape}")
        print(f"Model output: {output}")

        # Test başarılıysa çıktı
        print("Test passed!")

        break  # Test için sadece bir batch kullanıyoruz

if __name__ == "__main__":
    test_transformer()
# Out:
# Source batch: tensor([[0, 1, 1, 2, 3]])
# Target batch: tensor([[0, 1, 2, 3, 4]])
# Model output shape: torch.Size([1, 4, 10000])
# Model output: tensor([[[ 0.5742, -0.1234,  0.0070,  ..., -0.9092, -0.7915,  0.1211],
#          [ 1.3680, -0.1152,  0.6616,  ..., -0.8448, -0.7927,  0.3368],
#          [ 0.2621, -0.3701,  0.7028,  ..., -0.4670, -0.9505, -0.7050],
#          [ 0.7992,  0.0989,  0.6129,  ..., -0.6965, -1.2210, -0.0860]]],
#        grad_fn=<ViewBackward0>)
# Test passed!

# %%
import torch
import torch.nn as nn
import librosa
import math
import torch.optim as optim

# Ses Özellik Çıkarımı (MFCC)
def extract_mfcc(wav_file_path, n_mfcc=13):
    # Ses dosyasını yükle
    y, sr = librosa.load(wav_file_path)
    # MFCC özelliklerini çıkar
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    return torch.tensor(mfcc)

# Token Embedding Katmanı
class TokenEmbedding(nn.Module):
    def __init__(self, vocab_size, embed_size):
        super(TokenEmbedding, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_size)
        
    def forward(self, x):
        return self.embedding(x)

# Positional Encoding
class PositionalEncoding(nn.Module):
    def __init__(self, embed_size, max_len=512):
        super(PositionalEncoding, self).__init__()
        pe = torch.zeros(max_len, embed_size)
        for pos in range(max_len):
            for i in range(0, embed_size, 2):
                pe[pos, i] = math.sin(pos / (10000 ** ((2 * i)/embed_size)))
                pe[pos, i + 1] = math.cos(pos / (10000 ** ((2 * (i + 1))/embed_size)))
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)
        
    def forward(self, x):
        return x + self.pe[:, :x.size(1)]

# Self-Attention
class ScaledDotProductAttention(nn.Module):
    def __init__(self, d_k):
        super(ScaledDotProductAttention, self).__init__()
        self.d_k = d_k
    
    def forward(self, Q, K, V, mask=None):
        scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(self.d_k)
        if mask is not None:
            scores = scores.masked_fill(mask == 0, -1e9)
        attn = torch.nn.functional.softmax(scores, dim=-1)
        output = torch.matmul(attn, V)
        return output, attn

# Multi-Head Attention
class MultiHeadAttention(nn.Module):
    def __init__(self, heads, d_model):
        super(MultiHeadAttention, self).__init__()
        assert d_model % heads == 0
        self.d_k = d_model // heads
        self.heads = heads
        self.W_q = nn.Linear(d_model, d_model)
        self.W_k = nn.Linear(d_model, d_model)
        self.W_v = nn.Linear(d_model, d_model)
        self.fc = nn.Linear(d_model, d_model)
        self.attention = ScaledDotProductAttention(self.d_k)
    
    def forward(self, Q, K, V, mask=None):
        batch_size = Q.size(0)
        Q = self.W_q(Q).view(batch_size, -1, self.heads, self.d_k).transpose(1, 2)
        K = self.W_k(K).view(batch_size, -1, self.heads, self.d_k).transpose(1, 2)
        V = self.W_v(V).view(batch_size, -1, self.heads, self.d_k).transpose(1, 2)
        scores, attn = self.attention(Q, K, V, mask)
        scores = scores.transpose(1, 2).contiguous().view(batch_size, -1, self.heads * self.d_k)
        output = self.fc(scores)
        return output

# Encoder Katmanı
class EncoderLayer(nn.Module):
    def __init__(self, d_model, heads, d_ff, dropout=0.1):
        super(EncoderLayer, self).__init__()
        self.attention = MultiHeadAttention(heads, d_model)
        self.norm1 = nn.LayerNorm(d_model)
        self.ff = FeedForward(d_model, d_ff, dropout)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, mask=None):
        attn_output = self.attention(x, x, x, mask)
        x = self.norm1(x + self.dropout(attn_output))
        
        ff_output = self.ff(x)
        x = self.norm2(x + self.dropout(ff_output))
        return x

# Transformer Model
class Transformer(nn.Module):
    def __init__(self, src_vocab_size, tgt_vocab_size, d_model, N, heads, d_ff, dropout=0.1):
        super(Transformer, self).__init__()
        self.encoder = Encoder(src_vocab_size, d_model, N, heads, d_ff, dropout)
        self.fc_out = nn.Linear(d_model, tgt_vocab_size)
    
    def forward(self, src, src_mask=None):
        enc_output = self.encoder(src, src_mask)
        output = self.fc_out(enc_output)
        return output

# Eğitim ve Fine-Tuning
def train_model(model, data_loader, num_epochs=10):
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    model.train()

    for epoch in range(num_epochs):
        for src_batch in data_loader:
            optimizer.zero_grad()
            
            # Model çıkışı
            output = model(src_batch)

            # Loss hesaplama
            loss = torch.nn.functional.cross_entropy(output.view(-1, output.size(-1)), src_batch.view(-1))
            loss.backward()
            optimizer.step()

            print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item()}")

# Eğitim döngüsü için modelin başlatılması
src_vocab_size = 10000
tgt_vocab_size = 10000
d_model = 512
heads = 8
N = 6
d_ff = 2048
dropout = 0.1

model = Transformer(src_vocab_size, tgt_vocab_size, d_model, N, heads, d_ff, dropout)

# %%
#Adım 1: Modeli Fine-Tune Etme (Eğitim)

# %%
class Transformer(nn.Module):
    def __init__(self, src_vocab_size, tgt_vocab_size, d_model, N, heads, d_ff, dropout=0.1):
        super(Transformer, self).__init__()
        self.encoder = Encoder(src_vocab_size, d_model, N, heads, d_ff, dropout)
        self.decoder = Decoder(tgt_vocab_size, d_model, N, heads, d_ff, dropout)
        self.fc_out = nn.Linear(d_model, tgt_vocab_size)
    
    def forward(self, src, tgt, src_mask=None, tgt_mask=None):
        enc_output = self.encoder(src, src_mask)
        dec_output = self.decoder(tgt, enc_output, src_mask, tgt_mask)
        output = self.fc_out(dec_output)
        return output

    def make_masks(self, src, tgt):
        # Create padding mask for source and target sequences
        src_mask = create_padding_mask(src)
        tgt_padding_mask = create_padding_mask(tgt)
        
        # Create look-ahead mask for the target sequence
        look_ahead_mask = create_look_ahead_mask(tgt.size(1))
        tgt_mask = torch.max(tgt_padding_mask, look_ahead_mask)
        
        return src_mask, tgt_mask

# %%
# Padding Mask (prevents attention to padding tokens)
def create_padding_mask(seq):
    mask = (seq == 0).unsqueeze(1).unsqueeze(2)  # (batch_size, 1, 1, seq_len)
    return mask  # Mask with shape (batch_size, 1, 1, seq_len)

# Look-Ahead Mask (prevents attention to future tokens)
def create_look_ahead_mask(size):
    mask = torch.triu(torch.ones((size, size)), diagonal=1).type(torch.uint8)
    return mask  # Shape (seq_len, seq_len)

# %%
def train_model(model, data_loader, num_epochs=10):
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    model.train()

    for epoch in range(num_epochs):
        for src_batch, tgt_batch in data_loader:
            optimizer.zero_grad()
            
            # Model çıktısı
            src_input = src_batch
            tgt_input = tgt_batch[:, :-1]  # Hedef dilin input kısmı (son token hariç)
            tgt_output = tgt_batch[:, 1:]  # Hedef dilin output kısmı (ilk token hariç)
            
            # Maskeler
            src_mask, tgt_mask = model.make_masks(src_input, tgt_input)

            # Modelden geçiş
            output = model(src_input, tgt_input, src_mask, tgt_mask)

            # Kayıp hesaplama (cross-entropy loss)
            loss = F.cross_entropy(output.view(-1, output.size(-1)), tgt_output.view(-1))
            loss.backward()
            optimizer.step()

            print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item()}")

# %%
import librosa
import torch

def extract_mfcc(wav_file_path, n_mfcc=13):
    # Ses dosyasını yükle
    y, sr = librosa.load(wav_file_path)
    
    # MFCC özelliklerini çıkar
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    return torch.tensor(mfcc)

# Ses verisini işleme (feature extraction)
wav_file_path = "/teamspace/studios/this_studio/adsız.wav"
mfcc_features = extract_mfcc(wav_file_path)
print(f"MFCC Features shape: {mfcc_features.shape}")
# Out:
# MFCC Features shape: torch.Size([13, 1778])

# %%
import librosa
import torch

# Ses dosyasını yükleyip MFCC özelliklerini çıkarma
def extract_mfcc(wav_file_path, n_mfcc=13):
    y, sr = librosa.load(wav_file_path)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    return torch.tensor(mfcc)  # Bu MFCC verisini PyTorch tensor'üne dönüştürüyoruz.

# Test etme
wav_file_path = "/teamspace/studios/this_studio/adsız.wav"
mfcc_features = extract_mfcc(wav_file_path)
print("MFCC Features Shape:", mfcc_features.shape)
# Out:
# MFCC Features Shape: torch.Size([13, 1778])

# %%
from torch.utils.data import Dataset, DataLoader
import nltk
import torch

# Tokenizer functions using NLTK (örneğin İngilizce)
def tokenize_en(text):
    return nltk.word_tokenize(text)

def tokenize_de(text):
    return nltk.word_tokenize(text)

# Basit Vocabulary sınıfı
class Vocabulary:
    def __init__(self):
        self.word2idx = {}
        self.idx2word = {}
        self.idx = 0

    def add_word(self, word):
        if word not in self.word2idx:
            self.word2idx[word] = self.idx
            self.idx2word[self.idx] = word
            self.idx += 1

    def add_sentence(self, sentence):
        for word in sentence:
            self.add_word(word)

    def __len__(self):
        return len(self.word2idx)

    def numericalize(self, sentence):
        return [self.word2idx[word] for word in sentence]

# Dataset class using NLTK tokenization
class NLTKTranslationDataset(Dataset):
    def __init__(self, data, src_vocab, tgt_vocab, src_tokenizer, tgt_tokenizer):
        self.data = data
        self.src_vocab = src_vocab
        self.tgt_vocab = tgt_vocab
        self.src_tokenizer = src_tokenizer
        self.tgt_tokenizer = tgt_tokenizer

        # Build the vocabulary for both source and target languages
        for src_text, tgt_text in data:
            self.src_vocab.add_sentence(self.src_tokenizer(src_text))
            self.tgt_vocab.add_sentence(self.tgt_tokenizer(tgt_text))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        src_text, tgt_text = self.data[idx]
        src_tokens = self.src_tokenizer(src_text)
        tgt_tokens = self.tgt_tokenizer(tgt_text)
        src_indices = self.src_vocab.numericalize(src_tokens)
        tgt_indices = self.tgt_vocab.numericalize(tgt_tokens)
        return torch.tensor(src_indices), torch.tensor(tgt_indices)

# Veri yükleyicisini hazırlama
def prepare_data(batch_size=32):
    # Simüle edilmiş veri kümesi (gerçek bir veri kümesi kullanın)
    data = [("Hello world", "Hallo Welt"), ("How are you?", "Wie geht es Ihnen?")]

    # Vocab'ları oluştur
    src_vocab = Vocabulary()
    tgt_vocab = Vocabulary()

    # Dataset tanımlama
    dataset = NLTKTranslationDataset(data, src_vocab, tgt_vocab, tokenize_en, tokenize_de)

    # DataLoader için batchleme
    data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)

    return data_loader

# Collate function to pad sequences to the same length
def collate_fn(batch):
    src_batch, tgt_batch = zip(*batch)

    # Find the maximum length of source and target sequences in the batch
    src_max_len = max([len(src) for src in src_batch])
    tgt_max_len = max([len(tgt) for tgt in tgt_batch])

    # Padding token (assume 0 is the padding index)
    PAD_IDX = 0

    # Pad the source and target sequences
    src_padded = [src + [PAD_IDX] * (src_max_len - len(src)) for src in src_batch]
    tgt_padded = [tgt + [PAD_IDX] * (tgt_max_len - len(tgt)) for tgt in tgt_batch]

    # Convert the lists to PyTorch tensors
    src_tensor = torch.tensor(src_padded, dtype=torch.long)
    tgt_tensor = torch.tensor(tgt_padded, dtype=torch.long)

    return src_tensor, tgt_tensor

# %%
import torch

# Collate function to pad sequences to the same length
def collate_fn(batch):
    src_batch, tgt_batch = zip(*batch)

    # Find the maximum length of source and target sequences in the batch
    src_max_len = max([len(src) for src in src_batch])
    tgt_max_len = max([len(tgt) for tgt in tgt_batch])

    # Padding token (assume 0 is the padding index)
    PAD_IDX = 0

    # Pad the source and target sequences
    src_padded = [torch.cat([src, torch.tensor([PAD_IDX] * (src_max_len - len(src)), dtype=torch.long)]) for src in src_batch]
    tgt_padded = [torch.cat([tgt, torch.tensor([PAD_IDX] * (tgt_max_len - len(tgt)), dtype=torch.long)]) for tgt in tgt_batch]

    # Convert the lists to PyTorch tensors
    src_tensor = torch.stack(src_padded)
    tgt_tensor = torch.stack(tgt_padded)

    return src_tensor, tgt_tensor

# %%
import torch.optim as optim
import torch.nn.functional as F

# Eğitim fonksiyonu
def train_model(model, data_loader, num_epochs=10):
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    model.train()

    for epoch in range(num_epochs):
        total_loss = 0
        for src_batch, tgt_batch in data_loader:
            optimizer.zero_grad()

            # Model çıktısı
            src_input = src_batch
            tgt_input = tgt_batch[:, :-1]  # Hedef dilin input kısmı (son token hariç)
            tgt_output = tgt_batch[:, 1:]  # Hedef dilin output kısmı (ilk token hariç)

            # Maskeler
            src_mask, tgt_mask = model.make_masks(src_input, tgt_input)

            # Modelden geçiş
            output = model(src_input, tgt_input, src_mask, tgt_mask)  # Model çıktısını alıyoruz

            # Kayıp hesaplama (cross-entropy loss)
            output_reshaped = output.reshape(-1, output.size(-1))  # reshape kullanıldı
            tgt_output_reshaped = tgt_output.reshape(-1)  # reshape kullanıldı

            # Loss hesaplama
            loss = F.cross_entropy(output_reshaped, tgt_output_reshaped)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        print(f"Epoch [{epoch + 1}/{num_epochs}], Loss: {total_loss / len(data_loader)}")

    print("Training complete!")

# Modeli başlatma
src_vocab_size = 10000  # Gerçek vocab boyutunu burada kullanın
tgt_vocab_size = 10000  # Gerçek vocab boyutunu burada kullanın
d_model = 512
heads = 8
N = 6  # Encoder/Decoder katman sayısı
d_ff = 2048
dropout = 0.1

model = Transformer(src_vocab_size, tgt_vocab_size, d_model, N, heads, d_ff, dropout)

# Veri yükleyicisini hazırlama
wav_file_path = "/teamspace/studios/this_studio/adsız.wav"
data_loader = prepare_data(batch_size=2)

# Modeli eğitme
train_model(model, data_loader, num_epochs=10)
# Out:
# Epoch [1/10], Loss: 9.459457397460938
# Epoch [2/10], Loss: 3.6104846000671387
# Epoch [3/10], Loss: 6.658608913421631
# Epoch [4/10], Loss: 4.508923053741455
# Epoch [5/10], Loss: 2.6651952266693115
# Epoch [6/10], Loss: 2.409944772720337
# Epoch [7/10], Loss: 2.1607093811035156
# Epoch [8/10], Loss: 1.8063430786132812
# Epoch [9/10], Loss: 1.5469176769256592
# Epoch [10/10], Loss: 1.3235386610031128
# Training complete!

# %%
# Modeli kaydetme
torch.save(model.state_dict(), "transformer_model.pth")

# %%
# Modeli kaydetme
torch.save(model.state_dict(), "transformer_model.pth")

# Modeli yükleme
model = Transformer(src_vocab_size, tgt_vocab_size, d_model, N, heads, d_ff, dropout)
model.load_state_dict(torch.load("transformer_model.pth"))
model.eval()  # Modeli test aşamasına alıyoruz
# Out:
# Transformer(
#   (encoder): Encoder(
#     (embedding): TokenEmbedding(
#       (embedding): Embedding(10000, 512)
#     )
#     (positional_encoding): PositionalEncoding()
#     (layers): ModuleList(
#       (0-5): 6 x EncoderLayer(
#         (attention): MultiHeadAttention(
#           (W_q): Linear(in_features=512, out_features=512, bias=True)
#           (W_k): Linear(in_features=512, out_features=512, bias=True)
#           (W_v): Linear(in_features=512, out_features=512, bias=True)
#           (fc): Linear(in_features=512, out_features=512, bias=True)
#           (attention): ScaledDotProductAttention()
#         )
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (ff): FeedForward(
#           (fc1): Linear(in_features=512, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#         )
# ...

# %%
# Test fonksiyonu
def evaluate_model(model, data_loader):
    model.eval()  # Test moduna geç
    total_loss = 0
    with torch.no_grad():  # Gradient hesaplama gerekmiyor
        for src_batch, tgt_batch in data_loader:
            src_input = src_batch
            tgt_input = tgt_batch[:, :-1]
            tgt_output = tgt_batch[:, 1:]

            # Maskeler
            src_mask, tgt_mask = model.make_masks(src_input, tgt_input)

            # Modelden geçiş
            output = model(src_input, tgt_input, src_mask, tgt_mask)

            # Kayıp hesaplama
            output_reshaped = output.reshape(-1, output.size(-1))
            tgt_output_reshaped = tgt_output.reshape(-1)
            loss = F.cross_entropy(output_reshaped, tgt_output_reshaped)

            total_loss += loss.item()

    print(f"Test Loss: {total_loss / len(data_loader)}")

# Test veri yükleyicisini hazırlama
test_data_loader = prepare_data(batch_size=2)  # Burada test verisi yüklemeniz gerekecek

# Modeli test etme
evaluate_model(model, test_data_loader)
# Out:
# Test Loss: 1.1175020933151245

# %%
# Test örneği (çevrim yapma)
def generate_translation(model, src_sentence, src_vocab, tgt_vocab, unk_token="<UNK>"):
    model.eval()
    
    # Input'u token'lara çevirme
    src_tokens = tokenize_en(src_sentence)
    src_indices = torch.tensor([src_vocab.numericalize(src_tokens)], dtype=torch.long)

    # Maskeler oluşturma
    src_mask, tgt_mask = model.make_masks(src_indices, src_indices)  # Aynı zamanda hedef dil maskesini de oluştur

    # Modelin çevirisini üretme
    output = model(src_indices, src_indices, src_mask, tgt_mask)
    
    # Çıktıyı decode etme
    output_tokens = output.argmax(dim=-1).squeeze().tolist()  # en yüksek olasılıkları alıyoruz
    
    # Çıktıyı decode etme: Bilinmeyen token'lar için <UNK> kullanıyoruz
    translated_sentence = " ".join([tgt_vocab.idx2word.get(idx, unk_token) for idx in output_tokens])

    return translated_sentence

# Veri yükleyicisini hazırlama
data_loader, src_vocab, tgt_vocab = prepare_data(batch_size=2)

# Test örneği
src_sentence = "Hello world"
translated = generate_translation(model, src_sentence, src_vocab, tgt_vocab)
print(f"Translated sentence: {translated}")
# Out:
# Translated sentence: <UNK> <UNK>

# %%
import librosa
import torch

# Ses dosyasını yükleyip MFCC özelliklerini çıkarma
def extract_mfcc(wav_file_path, n_mfcc=13):
    y, sr = librosa.load(wav_file_path, sr=None)  # Ses dosyasını yükle
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)  # MFCC özelliklerini çıkar
    return torch.tensor(mfcc)  # Bu MFCC verisini PyTorch tensor'üne dönüştürüyoruz.

# Ses dosyasının yolu
wav_file_path = "/teamspace/studios/this_studio/adsız.wav"

# MFCC özelliklerini çıkarma
mfcc_features = extract_mfcc(wav_file_path)
print("MFCC Features Shape:", mfcc_features.shape)
# Out:
# MFCC Features Shape: torch.Size([13, 3555])

# %%
import librosa
import torch

# Ses dosyasını yükleyip MFCC özelliklerini çıkarma
def extract_mfcc(wav_file_path, n_mfcc=13):
    y, sr = librosa.load(wav_file_path, sr=None)  # Ses dosyasını yükle
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)  # MFCC özelliklerini çıkar
    return torch.tensor(mfcc, dtype=torch.float32)  # MFCC'yi float32 türünde döndürüyoruz

# Ses dosyasının yolu
wav_file_path = "/teamspace/studios/this_studio/adsız.wav"

# MFCC özelliklerini çıkarma
mfcc_features = extract_mfcc(wav_file_path)
print("MFCC Features Shape:", mfcc_features.shape)
# Out:
# MFCC Features Shape: torch.Size([13, 3555])

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import nltk

# Download the tokenizer models
nltk.download('punkt')

# Tokenizer functions using NLTK
def tokenize_en(text):
    return nltk.word_tokenize(text)

def tokenize_de(text):
    return nltk.word_tokenize(text)

# Simple Vocabulary to map words to integer indices
class Vocabulary:
    def __init__(self):
        self.word2idx = {}
        self.idx2word = {}
        self.idx = 0

    def add_word(self, word):
        if word not in self.word2idx:
            self.word2idx[word] = self.idx
            self.idx2word[self.idx] = word
            self.idx += 1

    def add_sentence(self, sentence):
        for word in sentence:
            self.add_word(word)

    def __len__(self):
        return len(self.word2idx)

    def numericalize(self, sentence):
        return [self.word2idx[word] for word in sentence]

# Dataset class using NLTK tokenization
class NLTKTranslationDataset(Dataset):
    def __init__(self, data, src_vocab, tgt_vocab, src_tokenizer, tgt_tokenizer):
        self.data = data
        self.src_vocab = src_vocab
        self.tgt_vocab = tgt_vocab
        self.src_tokenizer = src_tokenizer
        self.tgt_tokenizer = tgt_tokenizer

        # Build the vocabulary for both source and target languages
        for src_text, tgt_text in data:
            self.src_vocab.add_sentence(self.src_tokenizer(src_text))
            self.tgt_vocab.add_sentence(self.tgt_tokenizer(tgt_text))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        src_text, tgt_text = self.data[idx]
        src_tokens = self.src_tokenizer(src_text)
        tgt_tokens = self.tgt_tokenizer(tgt_text)
        src_indices = self.src_vocab.numericalize(src_tokens)
        tgt_indices = self.tgt_vocab.numericalize(tgt_tokens)
        return src_indices, tgt_indices

# Collate function to pad sequences to the same length
def collate_fn(batch):
    src_batch, tgt_batch = zip(*batch)

    # Find the maximum length of source and target sequences in the batch
    src_max_len = max([len(src) for src in src_batch])
    tgt_max_len = max([len(tgt) for tgt in tgt_batch])

    # Padding token (assume 0 is the padding index)
    PAD_IDX = 0

    # Pad the source and target sequences
    src_padded = [src + [PAD_IDX] * (src_max_len - len(src)) for src in src_batch]
    tgt_padded = [tgt + [PAD_IDX] * (tgt_max_len - len(tgt)) for tgt in tgt_batch]

    # Convert the lists to PyTorch tensors
    src_tensor = torch.tensor(src_padded, dtype=torch.long)
    tgt_tensor = torch.tensor(tgt_padded, dtype=torch.long)

    return src_tensor, tgt_tensor

def prepare_data(batch_size=32):
    # Simulated dataset (you can load a real dataset here)
    data = [("Hello world", "Hallo Welt"), ("How are you?", "Wie geht es Ihnen?")]

    # Create vocabularies
    src_vocab = Vocabulary()
    tgt_vocab = Vocabulary()

    # Define dataset
    dataset = NLTKTranslationDataset(data, src_vocab, tgt_vocab, tokenize_en, tokenize_de)

    # Create DataLoader for batching
    data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)

    return data_loader, src_vocab, tgt_vocab

# Transformer Model Code (Encoder, Decoder, etc.) goes here

# Training loop
def train(model, data_loader, epochs, criterion, optimizer):
    model.train()

    for epoch in range(epochs):
        total_loss = 0
        for src_batch, tgt_batch in data_loader:
            src_input = src_batch
            tgt_input = tgt_batch[:, :-1]  # Remove the last token for input
            tgt_output = tgt_batch[:, 1:]  # Remove the first token for output

            # Create masks (assume `make_masks()` creates the necessary padding and lookahead masks)
            src_mask, tgt_mask = model.make_masks(src_input, tgt_input)

            optimizer.zero_grad()

            # Forward pass
            output = model(src_input, tgt_input, src_mask, tgt_mask)

            # Reshape output to match dimensions for CrossEntropyLoss
            output = output.view(-1, output.size(-1))
            tgt_output = tgt_output.contiguous().view(-1)

            # Calculate loss
            loss = criterion(output, tgt_output)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        print(f"Epoch {epoch + 1}, Loss: {total_loss / len(data_loader)}")

    print("Training complete!")

if __name__ == "__main__":
    # Prepare data
    data_loader, src_vocab, tgt_vocab = prepare_data(batch_size=2)

    # Define the Transformer model (replace the vocab sizes with actual values)
    src_vocab_size = len(src_vocab)  # Replace with actual vocab size
    tgt_vocab_size = len(tgt_vocab)  # Replace with actual vocab size
    d_model = 512
    heads = 8
    N = 6  # Number of encoder/decoder layers
    d_ff = 2048
    dropout = 0.1

    model = Transformer(src_vocab_size, tgt_vocab_size, d_model, N, heads, d_ff, dropout)

    # Loss function and optimizer
    criterion = nn.CrossEntropyLoss(ignore_index=0)  # Assuming 0 is the padding index
    optimizer = optim.Adam(model.parameters(), lr=0.0001)

    # Train the model
    train(model, data_loader, epochs=10, criterion=criterion, optimizer=optimizer)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /teamspace/studios/this_studio/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Epoch 1, Loss: 1.8021748065948486
# Epoch 2, Loss: 0.8246005773544312
# Epoch 3, Loss: 0.521083414554596
# Epoch 4, Loss: 0.24862618744373322
# Epoch 5, Loss: 0.07238420099020004
# Epoch 6, Loss: 0.0520518496632576
# Epoch 7, Loss: 0.023983608931303024
# Epoch 8, Loss: 0.00989394448697567
# Epoch 9, Loss: 0.006927252747118473
# Epoch 10, Loss: 0.004079961683601141
# Training complete!

# %%
torch.save(model.state_dict(), 'transformer_model.pth')

# %%
import nltk
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
import torch.optim as optim
import math

# Download the tokenizer models
nltk.download('punkt')

# Tokenizer functions using NLTK
def tokenize_en(text):
    return nltk.word_tokenize(text)

def tokenize_de(text):
    return nltk.word_tokenize(text)

# Simple Vocabulary to map words to integer indices
class Vocabulary:
    def __init__(self):
        self.word2idx = {}
        self.idx2word = {}
        self.idx = 0

    def add_word(self, word):
        if word not in self.word2idx:
            self.word2idx[word] = self.idx
            self.idx2word[self.idx] = word
            self.idx += 1

    def add_sentence(self, sentence):
        for word in sentence:
            self.add_word(word)

    def __len__(self):
        return len(self.word2idx)

    def numericalize(self, sentence):
        return [self.word2idx[word] for word in sentence]

# Dataset class using NLTK tokenization
class NLTKTranslationDataset(Dataset):
    def __init__(self, data, src_vocab, tgt_vocab, src_tokenizer, tgt_tokenizer):
        self.data = data
        self.src_vocab = src_vocab
        self.tgt_vocab = tgt_vocab
        self.src_tokenizer = src_tokenizer
        self.tgt_tokenizer = tgt_tokenizer

        # Build the vocabulary for both source and target languages
        for src_text, tgt_text in data:
            self.src_vocab.add_sentence(self.src_tokenizer(src_text))
            self.tgt_vocab.add_sentence(self.tgt_tokenizer(tgt_text))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        src_text, tgt_text = self.data[idx]
        src_tokens = self.src_tokenizer(src_text)
        tgt_tokens = self.tgt_tokenizer(tgt_text)
        src_indices = self.src_vocab.numericalize(src_tokens)
        tgt_indices = self.tgt_vocab.numericalize(tgt_tokens)
        return src_indices, tgt_indices

def prepare_data(batch_size=32):
    # Simulated dataset (you can load a real dataset here)
    data = [("Hello world", "Hallo Welt"), ("How are you?", "Wie geht es Ihnen?")]

    # Create vocabularies
    src_vocab = Vocabulary()
    tgt_vocab = Vocabulary()

    # Define dataset
    dataset = NLTKTranslationDataset(data, src_vocab, tgt_vocab, tokenize_en, tokenize_de)

    # Create DataLoader for batching
    data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)

    return data_loader

# Collate function to pad sequences to the same length
def collate_fn(batch):
    src_batch, tgt_batch = zip(*batch)

    # Find the maximum length of source and target sequences in the batch
    src_max_len = max([len(src) for src in src_batch])
    tgt_max_len = max([len(tgt) for tgt in tgt_batch])

    # Padding token (assume 0 is the padding index)
    PAD_IDX = 0

    # Pad the source and target sequences
    src_padded = [src + [PAD_IDX] * (src_max_len - len(src)) for src in src_batch]
    tgt_padded = [tgt + [PAD_IDX] * (tgt_max_len - len(tgt)) for tgt in tgt_batch]

    # Convert the lists to PyTorch tensors
    src_tensor = torch.tensor(src_padded, dtype=torch.long)
    tgt_tensor = torch.tensor(tgt_padded, dtype=torch.long)

    return src_tensor, tgt_tensor


# Positional Encoding
class PositionalEncoding(nn.Module):
    def __init__(self, embed_size, max_len=512):
        super(PositionalEncoding, self).__init__()
        pe = torch.zeros(max_len, embed_size)
        for pos in range(max_len):
            for i in range(0, embed_size, 2):
                pe[pos, i] = math.sin(pos / (10000 ** ((2 * i)/embed_size)))
                pe[pos, i + 1] = math.cos(pos / (10000 ** ((2 * (i + 1))/embed_size)))
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)
        
    def forward(self, x):
        return x + self.pe[:, :x.size(1)]

# Scaled Dot-Product Attention
class ScaledDotProductAttention(nn.Module):
    def __init__(self, d_k):
        super(ScaledDotProductAttention, self).__init__()
        self.d_k = d_k
    
    def forward(self, Q, K, V, mask=None):
        scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(self.d_k)
        if mask is not None:
            scores = scores.masked_fill(mask == 0, -1e9)
        attn = torch.nn.functional.softmax(scores, dim=-1)
        output = torch.matmul(attn, V)
        return output, attn

# Multi-Head Attention
class MultiHeadAttention(nn.Module):
    def __init__(self, heads, d_model):
        super(MultiHeadAttention, self).__init__()
        assert d_model % heads == 0
        self.d_k = d_model // heads
        self.heads = heads
        self.W_q = nn.Linear(d_model, d_model)
        self.W_k = nn.Linear(d_model, d_model)
        self.W_v = nn.Linear(d_model, d_model)
        self.fc = nn.Linear(d_model, d_model)
        self.attention = ScaledDotProductAttention(self.d_k)
    
    def forward(self, Q, K, V, mask=None):
        batch_size = Q.size(0)
        Q = self.W_q(Q).view(batch_size, -1, self.heads, self.d_k).transpose(1, 2)
        K = self.W_k(K).view(batch_size, -1, self.heads, self.d_k).transpose(1, 2)
        V = self.W_v(V).view(batch_size, -1, self.heads, self.d_k).transpose(1, 2)
        scores, attn = self.attention(Q, K, V, mask)
        scores = scores.transpose(1, 2).contiguous().view(batch_size, -1, self.heads * self.d_k)
        output = self.fc(scores)
        return output

# Feedforward Layer
class FeedForward(nn.Module):
    def __init__(self, d_model, d_ff, dropout=0.1):
        super(FeedForward, self).__init__()
        self.fc1 = nn.Linear(d_model, d_ff)
        self.fc2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.dropout(self.relu(self.fc1(x)))
        x = self.fc2(x)
        return x

# Encoder Layer
class EncoderLayer(nn.Module):
    def __init__(self, d_model, heads, d_ff, dropout=0.1):
        super(EncoderLayer, self).__init__()
        self.attention = MultiHeadAttention(heads, d_model)
        self.norm1 = nn.LayerNorm(d_model)
        self.ff = FeedForward(d_model, d_ff, dropout)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, mask=None):
        # Multi-head attention with residual connection and layer normalization
        attn_output = self.attention(x, x, x, mask)
        x = self.norm1(x + self.dropout(attn_output))
        
        # Feedforward network with residual connection and layer normalization
        ff_output = self.ff(x)
        x = self.norm2(x + self.dropout(ff_output))
        return x

# Encoder
class Encoder(nn.Module):
    def __init__(self, vocab_size, d_model, N, heads, d_ff, dropout=0.1):
        super(Encoder, self).__init__()
        self.embedding = TokenEmbedding(vocab_size, d_model)
        self.positional_encoding = PositionalEncoding(d_model)
        self.layers = nn.ModuleList([EncoderLayer(d_model, heads, d_ff, dropout) for _ in range(N)])
        self.dropout = nn.Dropout(dropout)
    
    def forward(self, x, mask=None):
        x = self.embedding(x)
        x = self.positional_encoding(x)
        for layer in self.layers:
            x = layer(x, mask)
        return x

# Decoder Layer
class DecoderLayer(nn.Module):
    def __init__(self, d_model, heads, d_ff, dropout=0.1):
        super(DecoderLayer, self).__init__()
        self.attention = MultiHeadAttention(heads, d_model)
        self.encoder_attention = MultiHeadAttention(heads, d_model)
        self.ff = FeedForward(d_model, d_ff, dropout)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, enc_output, src_mask=None, tgt_mask=None):
        # Self-attention with residual connection and layer normalization
        attn_output = self.attention(x, x, x, tgt_mask)
        x = self.norm1(x + self.dropout(attn_output))

        # Attention over encoder output
        attn_output = self.encoder_attention(x, enc_output, enc_output, src_mask)
        x = self.norm2(x + self.dropout(attn_output))

        # Feedforward network with residual connection and layer normalization
        ff_output = self.ff(x)
        x = self.norm3(x + self.dropout(ff_output))
        return x

# Decoder
class Decoder(nn.Module):
    def __init__(self, vocab_size, d_model, N, heads, d_ff, dropout=0.1):
        super(Decoder, self).__init__()
        self.embedding = TokenEmbedding(vocab_size, d_model)
        self.positional_encoding = PositionalEncoding(d_model)
        self.layers = nn.ModuleList([DecoderLayer(d_model, heads, d_ff, dropout) for _ in range(N)])
        self.dropout = nn.Dropout(dropout)
    
    def forward(self, x, enc_output, src_mask=None, tgt_mask=None):
        x = self.embedding(x)
        x = self.positional_encoding(x)
        for layer in self.layers:
            x = layer(x, enc_output, src_mask, tgt_mask)
        return x

# Transformer Model
class Transformer(nn.Module):
    def __init__(self, src_vocab_size, tgt_vocab_size, d_model, N, heads, d_ff, dropout=0.1):
        super(Transformer, self).__init__()
        self.encoder = Encoder(src_vocab_size, d_model, N, heads, d_ff, dropout)
        self.decoder = Decoder(tgt_vocab_size, d_model, N, heads, d_ff, dropout)
        self.fc_out = nn.Linear(d_model, tgt_vocab_size)
    
    def forward(self, src, tgt, src_mask=None, tgt_mask=None):
        enc_output = self.encoder(src, src_mask)
        dec_output = self.decoder(tgt, enc_output, src_mask, tgt_mask)
        output = self.fc_out(dec_output)
        return output

    def make_masks(self, src, tgt):
        # Create padding mask for source and target sequences
        src_mask = create_padding_mask(src)
        tgt_padding_mask = create_padding_mask(tgt)
        
        # Create look-ahead mask for the target sequence
        look_ahead_mask = create_look_ahead_mask(tgt.size(1))
        tgt_mask = torch.max(tgt_padding_mask, look_ahead_mask)
        
        return src_mask, tgt_mask

# Padding Mask (prevents attention to padding tokens)
def create_padding_mask(seq):
    mask = (seq == 0).unsqueeze(1).unsqueeze(2)  # (batch_size, 1, 1, seq_len)
    return mask  # Mask with shape (batch_size, 1, 1, seq_len)

# Look-Ahead Mask (prevents attention to future tokens)
def create_look_ahead_mask(size):
    mask = torch.triu(torch.ones((size, size)), diagonal=1).type(torch.uint8)
    return mask  # Shape (seq_len, seq_len)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /teamspace/studios/this_studio/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import torch
import torch.optim as optim
import torch.nn as nn

# Model parameters
src_vocab_size = len(src_vocab)  # Source vocabulary size
tgt_vocab_size = len(tgt_vocab)  # Target vocabulary size
d_model = 512
heads = 8
N = 6  # Number of encoder and decoder layers
d_ff = 2048
dropout = 0.1

# Initialize the model
model = Transformer(src_vocab_size, tgt_vocab_size, d_model, N, heads, d_ff, dropout)

# Loss function and optimizer
criterion = nn.CrossEntropyLoss(ignore_index=0)  # Ignore padding token (0)
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# Training loop
def train(model, data_loader, epochs, criterion, optimizer):
    model.train()

    for epoch in range(epochs):
        total_loss = 0
        for src_batch, tgt_batch in data_loader:
            src_input = src_batch
            tgt_input = tgt_batch[:, :-1]  # Remove the last token for input
            tgt_output = tgt_batch[:, 1:]  # Remove the first token for output

            # Create masks
            src_mask, tgt_mask = model.make_masks(src_input, tgt_input)

            optimizer.zero_grad()

            # Forward pass
            output = model(src_input, tgt_input, src_mask, tgt_mask)

            # Reshape output for CrossEntropyLoss
            output = output.view(-1, output.size(-1))
            tgt_output = tgt_output.contiguous().view(-1)

            # Calculate loss
            loss = criterion(output, tgt_output)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        print(f"Epoch {epoch + 1}, Loss: {total_loss / len(data_loader)}")

    print("Training complete!")

# Train the model
data_loader = prepare_data(batch_size=32)  # Prepare your data
train(model, data_loader, epochs=10, criterion=criterion, optimizer=optimizer)
# Out:
# Epoch 1, Loss: 2.0115857124328613
# Epoch 2, Loss: 0.7099840641021729
# Epoch 3, Loss: 0.5310801267623901
# Epoch 4, Loss: 0.1894005835056305
# Epoch 5, Loss: 0.1269707828760147
# Epoch 6, Loss: 0.047401390969753265
# Epoch 7, Loss: 0.01564166322350502
# Epoch 8, Loss: 0.007387460209429264
# Epoch 9, Loss: 0.004666213411837816
# Epoch 10, Loss: 0.004843265749514103
# Training complete!

# %%
def test_transformer(model, data_loader):
    model.eval()  # Set the model to evaluation mode

    for src_batch, tgt_batch in data_loader:
        print(f"Source batch: {src_batch}")
        print(f"Target batch: {tgt_batch}")

        # Prepare input and output for the model
        src_input = src_batch
        tgt_input = tgt_batch[:, :-1]  # Remove the last token for input
        tgt_output = tgt_batch[:, 1:]  # Remove the first token for output

        # Create masks for source and target inputs
        src_mask, tgt_mask = model.make_masks(src_input, tgt_input)

        # Forward pass through the model
        with torch.no_grad():  # No backpropagation during testing
            output = model(src_input, tgt_input, src_mask, tgt_mask)

        print(f"Model output shape: {output.shape}")
        print(f"Model output: {output}")

        break  # Test with a single batch

# Test the model
test_transformer(model, data_loader)
# Out:
# Source batch: tensor([[0, 1, 0, 0],
#         [2, 3, 4, 5]])
# Target batch: tensor([[0, 1, 0, 0, 0],
#         [2, 3, 4, 5, 6]])
# Model output shape: torch.Size([2, 4, 7])
# Model output: tensor([[[-2.0718,  8.4297, -1.5445, -1.3066, -1.6825, -0.6662, -1.1483],
#          [-2.0711,  7.8576, -1.5423, -0.9922, -1.6021, -0.9458, -1.3362],
#          [-2.1638,  8.3618, -1.4830, -1.2386, -1.7334, -0.6746, -1.1046],
#          [-2.1800,  8.3624, -1.4751, -1.2312, -1.7417, -0.6937, -1.0555]],
#
#         [[-1.2170, -0.7318, -1.9096,  7.2114, -2.6243, -1.2923, -1.5996],
#          [-2.0738, -1.0524, -1.6000, -0.2121,  6.2297, -0.0576, -2.7462],
#          [-2.1748, -1.3399, -1.6797, -1.7003, -1.3994,  8.3788, -1.9413],
#          [-1.6528, -0.2937, -0.7135,  0.1042, -3.2500, -0.2935,  6.6565]]])

# %%
def generate_translation(model, src_sentence, src_vocab, tgt_vocab):
    # Tokenize the source sentence
    src_tokens = tokenize_en(src_sentence)
    src_indices = torch.tensor([src_vocab.numericalize(src_tokens)], dtype=torch.long)

    # Create padding mask
    src_mask = create_padding_mask(src_indices)

    # Target input (start of sequence token, e.g., "<sos>")
    tgt_input = torch.tensor([[tgt_vocab.word2idx["<sos>"]]], dtype=torch.long)

    # Generate output with the model
    model.eval()
    with torch.no_grad():
        output = model(src_indices, tgt_input, src_mask, src_mask)

    # Decode the output to words (argmax gives indices of highest probabilities)
    output_tokens = output.argmax(dim=-1).squeeze().tolist()  # Convert tensor to list of indices

    # Decode indices into words
    translated_sentence = " ".join([tgt_vocab.idx2word.get(idx, "<unk>") for idx in output_tokens])

    return translated_sentence

# %%
import nltk
from torch.utils.data import Dataset, DataLoader
import torch

# NLTK tokenization (Word Tokenizer)
nltk.download('punkt')

# Tokenizer functions
def tokenize_en(text):
    return nltk.word_tokenize(text)

def tokenize_de(text):
    return nltk.word_tokenize(text)

# Vocabulary class for source and target languages
class Vocabulary:
    def __init__(self):
        self.word2idx = {}
        self.idx2word = {}
        self.idx = 0

    def add_word(self, word):
        if word not in self.word2idx:
            self.word2idx[word] = self.idx
            self.idx2word[self.idx] = word
            self.idx += 1

    def add_sentence(self, sentence):
        for word in sentence:
            self.add_word(word)

    def __len__(self):
        return len(self.word2idx)

    def numericalize(self, sentence):
        return [self.word2idx.get(word, self.word2idx["<unk>"]) for word in sentence]

# Define a Dataset class for the translation task
class NLTKTranslationDataset(Dataset):
    def __init__(self, data, src_vocab, tgt_vocab, src_tokenizer, tgt_tokenizer):
        self.data = data
        self.src_vocab = src_vocab
        self.tgt_vocab = tgt_vocab
        self.src_tokenizer = src_tokenizer
        self.tgt_tokenizer = tgt_tokenizer

        for src_text, tgt_text in data:
            self.src_vocab.add_sentence(self.src_tokenizer(src_text))
            self.tgt_vocab.add_sentence(self.tgt_tokenizer(tgt_text))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        src_text, tgt_text = self.data[idx]
        src_tokens = self.src_tokenizer(src_text)
        tgt_tokens = self.tgt_tokenizer(tgt_text)
        src_indices = self.src_vocab.numericalize(src_tokens)
        tgt_indices = self.tgt_vocab.numericalize(tgt_tokens)
        return src_indices, tgt_indices

# Prepare your data for model training or inference
def prepare_data(batch_size=32):
    # Example data (you should replace it with real data)
    data = [("Hello world", "Hallo Welt"), ("How are you?", "Wie geht es Ihnen?")]

    # Create vocabularies
    src_vocab = Vocabulary()
    tgt_vocab = Vocabulary()

    # Define the dataset
    dataset = NLTKTranslationDataset(data, src_vocab, tgt_vocab, tokenize_en, tokenize_de)

    # DataLoader to handle batching
    data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)

    return data_loader, src_vocab, tgt_vocab

# Collate function to pad sequences to the same length
def collate_fn(batch):
    src_batch, tgt_batch = zip(*batch)

    src_max_len = max([len(src) for src in src_batch])
    tgt_max_len = max([len(tgt) for tgt in tgt_batch])

    PAD_IDX = 0

    src_padded = [src + [PAD_IDX] * (src_max_len - len(src)) for src in src_batch]
    tgt_padded = [tgt + [PAD_IDX] * (tgt_max_len - len(tgt)) for tgt in tgt_batch]

    src_tensor = torch.tensor(src_padded, dtype=torch.long)
    tgt_tensor = torch.tensor(tgt_padded, dtype=torch.long)

    return src_tensor, tgt_tensor

# Prepare the data loader
data_loader, src_vocab, tgt_vocab = prepare_data(batch_size=2)

# Now your data_loader is ready to be used
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /teamspace/studios/this_studio/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
pip install torchaudio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

file_path = '/teamspace/studios/this_studio/adsız.wav'

if os.path.exists(file_path):
    print("Dosya bulundu!")
else:
    print("Dosya bulunamadı!")
# Out:
# Dosya bulundu!

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# File path
file_path = '/teamspace/studios/this_studio/adsız.wav'

# Load audio file
y, sr = librosa.load(file_path)

# Compute MFCC
mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)

# Plot the MFCC
plt.figure(figsize=(10, 6))
librosa.display.specshow(mfcc, x_axis='time', sr=sr)
plt.colorbar()
plt.title('MFCC')
plt.show()

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# Ses dosyasını yükleyelim
file_path = '/teamspace/studios/this_studio/adsız.wav'  # Ses dosyasının yolu
y, sr = librosa.load(file_path, sr=None)

# MFCC Hesaplaması
mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)

# MFCC'yi görselleştirelim
plt.figure(figsize=(10, 6))
librosa.display.specshow(mfcc, x_axis='time', sr=sr, cmap='coolwarm')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC Özelliklerinin Görselleştirilmesi')
plt.show()

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# Ses dosyasını yükleyelim
file_path = '/teamspace/studios/this_studio/adsız.wav'  # Ses dosyasının yolu
y, sr = librosa.load(file_path, sr=None)

# MFCC Hesaplaması (13 katsayı, 20 ms'lik pencerelerle)
mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13, hop_length=512)

# MFCC'yi görselleştirelim
plt.figure(figsize=(10, 6))
librosa.display.specshow(mfcc, x_axis='time', sr=sr, cmap='coolwarm')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC Özelliklerinin Görselleştirilmesi')
plt.show()

# Tokenları görselleştirmenin bir yolu: her bir MFCC'nin katsayısını bir token olarak alıp onları sırayla yazdırmak
# Bu örnekte, MFCC'nin her bir katsayısının bir token gibi işlev gördüğü basit bir örnek.

# Örneğin, her MFCC katsayısını 1'e bölelim (daha basit olması açısından), böylece token'ları temsil etmiş olalım:
tokens = np.round(mfcc, 2)

# İlk 10 token'ı görüntüleyelim
print("İlk 10 token (MFCC katsayıları):")
print(tokens[:, :10])  # İlk 10 zaman dilimi
# Out:
# İlk 10 token (MFCC katsayıları):
# [[-5.2180e+02 -5.1073e+02 -5.0995e+02 -5.0921e+02 -5.1195e+02 -5.1250e+02
#   -5.1216e+02 -5.1271e+02 -5.1126e+02 -5.1218e+02]
#  [ 5.3450e+01  6.6600e+01  6.8560e+01  6.9910e+01  6.6250e+01  6.5530e+01
#    6.5850e+01  6.4740e+01  6.6300e+01  6.5110e+01]
#  [ 3.9040e+01  4.5910e+01  4.9610e+01  5.1630e+01  4.8540e+01  4.7990e+01
#    4.8440e+01  4.6870e+01  4.7030e+01  4.6100e+01]
#  [ 2.2560e+01  2.2420e+01  2.6900e+01  2.9350e+01  2.7020e+01  2.6710e+01
#    2.8840e+01  2.7620e+01  2.5840e+01  2.5140e+01]
#  [ 1.0610e+01  5.6300e+00  8.5200e+00  1.0820e+01  9.1500e+00  9.3200e+00
#    1.4850e+01  1.5140e+01  1.1570e+01  1.0890e+01]
#  [ 6.1600e+00 -1.1000e-01 -9.1000e-01  6.3000e-01 -7.5000e-01  4.1000e-01
#    9.4300e+00  1.1560e+01  7.2500e+00  6.2800e+00]
#  [ 7.5300e+00  2.9800e+00 -1.6400e+00 -1.1600e+00 -2.7400e+00 -1.9000e-01
#    9.9700e+00  1.2800e+01  9.4000e+00  8.0400e+00]
# ...

# %%
import torch
import librosa
import matplotlib.pyplot as plt
import numpy as np

# Ses dosyasını yükleyelim
file_path = '/teamspace/studios/this_studio/adsız.wav'  # Ses dosyasının yolu
y, sr = librosa.load(file_path, sr=None)

# MFCC Hesaplaması (13 katsayı, 20 ms'lik pencerelerle)
mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13, hop_length=512)

# MFCC'yi görselleştirelim
plt.figure(figsize=(10, 6))
librosa.display.specshow(mfcc, x_axis='time', sr=sr, cmap='coolwarm')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC Özelliklerinin Görselleştirilmesi')
plt.show()

# Tokenlaştırma (MFCC katsayılarını token olarak kullanma)
# Burada her MFCC katsayısı bir token olarak kabul edilir
tokens = np.round(mfcc, 2)  # Tokenları sayısal hale getirmek için yuvarlıyoruz

# Zamanla tokenların değişimini görmek için her bir tokenın değerini çiziyoruz
plt.figure(figsize=(10, 6))

# İlk MFCC katsayısının zaman içerisindeki değişimini çiziyoruz
plt.plot(tokens[0, :], label='MFCC 1. Katsayı')

# 2. MFCC katsayısını da çiziyoruz
plt.plot(tokens[1, :], label='MFCC 2. Katsayı')

# 3. MFCC katsayısını çiziyoruz
plt.plot(tokens[2, :], label='MFCC 3. Katsayı')

plt.title('Zaman İçindeki Token Değişimi')
plt.xlabel('Zaman (frames)')
plt.ylabel('Token Değerleri (MFCC Katsayıları)')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %%
import torch
import torch.nn as nn
import librosa
import numpy as np
import matplotlib.pyplot as plt

# Ses dosyasını yükleyelim
file_path = '/teamspace/studios/this_studio/adsız.wav'  # Ses dosyasının yolu
y, sr = librosa.load(file_path, sr=None)

# MFCC Hesaplaması (13 katsayı, 20 ms'lik pencerelerle)
mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13, hop_length=512)

# MFCC'yi görselleştirelim
plt.figure(figsize=(10, 6))
librosa.display.specshow(mfcc, x_axis='time', sr=sr, cmap='coolwarm')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC Özelliklerinin Görselleştirilmesi')
plt.show()

# Tokenlaştırma (MFCC katsayılarını token olarak kullanma)
# MFCC değerlerini belirli bir aralıkta sınırlıyoruz (0 ile 99 arasında)
tokens = np.round(mfcc, 2)  # MFCC katsayılarını yuvarlıyoruz
tokens = tokens.astype(int)  # Tokenları int tipine dönüştürüyoruz

# Tokenları 0-99 arası bir aralığa sınırlıyoruz
tokens = np.clip(tokens, 0, 99)

# Şimdi bu tokenları bir Tensor'a çevireceğiz
tokens_tensor = torch.tensor(tokens, dtype=torch.long)

# Embedding Katmanını tanımlayalım
# Burada n_tokens = 100 (token sayısı) ve embedding_dim = 64 (embedding boyutu)
n_tokens = 100  # Token sayısı, MFCC'nin tokenlara dönüştürülmesi
embedding_dim = 64  # Embedding boyutu
embedding_layer = nn.Embedding(n_tokens, embedding_dim)

# MFCC özelliklerinin tokenlarını embedding katmanına besliyoruz
embeddings = embedding_layer(tokens_tensor)

# Sonuçları görselleştirelim
print(embeddings.shape)  # Bu, [n_mfcc, sequence_length, embedding_dim] şeklinde olacaktır

# Embedding'leri görselleştirelim
plt.figure(figsize=(10, 6))
for i in range(embedding_dim):
    plt.plot(embeddings[:, 0, i].detach().numpy(), label=f'Embedding {i+1}')

plt.title('Embeddings Özelliklerinin Zaman İçindeki Değişimi')
plt.xlabel('Zaman (frames)')
plt.ylabel('Embedding Değeri')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# torch.Size([13, 3555, 64])

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create a directed graph
G = nx.DiGraph()

# Add nodes
G.add_node("Raw Audio Data")
G.add_node("Spectral Estimation (MFCC, STFT)")
G.add_node("Tokenization")
G.add_node("Embedding")
G.add_node("LLM Processing")

# Add edges to represent the flow
G.add_edge("Raw Audio Data", "Spectral Estimation (MFCC, STFT)")
G.add_edge("Spectral Estimation (MFCC, STFT)", "Tokenization")
G.add_edge("Tokenization", "Embedding")
G.add_edge("Embedding", "LLM Processing")

# Create a plot
plt.figure(figsize=(10, 6))

# Draw the graph
pos = nx.spring_layout(G, seed=42)  # Layout of the graph
nx.draw(G, pos, with_labels=True, node_size=3000, node_color='skyblue', font_size=12, font_weight='bold', edge_color='black')

# Set plot title
plt.title("Relationship Between Spectral Estimation and LLMs", fontsize=14)

# Show the plot
plt.show()
